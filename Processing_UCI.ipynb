# %%
#test comment
import pandas as pd

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.original 
y = heart_disease.data.targets 
  
# metadata 
print(heart_disease.metadata) 
  
# variable information 
heart_disease.data.variablesW
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
# get the data dictionary
for i in heart_disease.variables: 
    print(i)
# Out:
# name
# role
# type
# demographic
# description
# units
# missing_values

# %%
heart_disease.variables.to_csv('./Data Dictionary/UCI_DD.csv')

# %%
# 1 is male and 0 is female
df = heart_disease.data.original

# %%
# get the data dictionary 
heart_disease.variablesW

# %%
df = df.rename(columns = {'age': 'Age', 'sex':'Sex', 'trestbps':'Systolic BP', 'chol':'Cholesterol', 'thalach':'Max Heart Rate', 'num':'Result', 'fbs': 'Fasting Blood Sugar'})

# %%
df['Sex'] = df['Sex'].apply(lambda x: 'Male' if x == 1 else 'Female')

# %%
df['Data Set'] = 'UC Irvine'

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'Systolic BP', 'Cholesterol', 'Fasting Blood Sugar',
#        'restecg', 'Max Heart Rate', 'exang', 'oldpeak', 'slope', 'ca', 'thal',
#        'Result', 'Data Set'],
#       dtype='object')

# %%
df[['Age', 'Sex', 'Systolic BP', 'Cholesterol', 'Max Heart Rate', 'Result', 'Fasting Blood Sugar', 'Data Set']]
# Out:
#      Age     Sex  Systolic BP  Cholesterol  Max Heart Rate  Result  \
# 0     63    Male          145          233             150       0
# 1     67    Male          160          286             108       2
# 2     67    Male          120          229             129       1
# 3     37    Male          130          250             187       0
# 4     41  Female          130          204             172       0
# ..   ...     ...          ...          ...             ...     ...
# 298   45    Male          110          264             132       1
# 299   68    Male          144          193             141       2
# 300   57    Male          130          131             115       3
# 301   57  Female          130          236             174       1
# 302   38    Male          138          175             173       0
#
#      Fasting Blood Sugar   Data Set
# 0                      1  UC Irvine
# 1                      0  UC Irvine
# 2                      0  UC Irvine
# ...

# %%
dd = pd.read_csv('./Data Dictionary/Framingham_DD.csv', header=0)
dd
# Out:
#           Column ID       Column Type  \
# 0              male  Integer (binary)
# 1               Age           Integer
# 2         education           Integer
# 3     currentSmoker  Integer (binary)
# 4        cigsPerDay           Numeric
# 5            BPMeds  Integer (binary)
# 6   prevalentStroke  Integer (binary)
# 7      prevalentHyp  Integer (binary)
# 8          diabetes  Integer (binary)
# 9       Cholesterol           Integer
# 10            sysBP             Float
# 11            diaBP             Float
# 12              BMI             Float
# 13        heartRate           Integer
# 14          Glucose           Integer
# 15           Result  Integer (binary)
# 16              NaN               NaN
# 17              NaN               NaN
# 18              NaN               NaN
# 19              NaN               NaN
# 20              NaN               NaN
# 21              NaN               NaN
#
#                                      Data Description  \
# ...
